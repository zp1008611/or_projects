# %%
import numpy as np
import math
import pandas as pd
import gurobipy as gp
from gurobipy import GRB
import time
import networkx as nx
from cspy import BiDirectional
import os

# %% [markdown]
# # Read data

# %%
def preprocess_cvrp(data_file):
    # Step 1: Read and parse the data
    with open(data_file, "r") as file:
        lines = file.readlines()
    
    # Extract sections
    node_coord_section = []
    demand_section = []
    capacity = 0
    depot = 0
    
    current_section = None
    for line in lines:
        line = line.strip()
        if line.startswith("NODE_COORD_SECTION"):
            current_section = "NODE_COORD"
        elif line.startswith("DEMAND_SECTION"):
            current_section = "DEMAND"
        elif line.startswith("DEPOT_SECTION"):
            current_section = "DEPOT"
        elif line.startswith("CAPACITY"):
            capacity = int(line.split(":")[1])
        elif current_section == "NODE_COORD" and line and not line.startswith("EOF"):
            parts = list(map(int, line.split()))
            node_coord_section.append((parts[0], parts[1], parts[2]))
        elif current_section == "DEMAND" and line and not line.startswith("EOF"):
            parts = list(map(int, line.split()))
            demand_section.append((parts[0], parts[1]))
        elif current_section == "DEPOT" and line and not line.startswith("EOF"):
            if depot == 1:
                continue
            depot = int(line)
            # print(depot)

    # Convert to pandas DataFrames
    nodes_df = pd.DataFrame(node_coord_section, columns=["Node", "X", "Y"])
    demands_df = pd.DataFrame(demand_section, columns=["Node", "Demand"])

    # Step 2: Compute distance matrix
    num_nodes = len(nodes_df)
    distance_matrix = np.zeros((num_nodes, num_nodes))

    for i in range(num_nodes):
        for j in range(num_nodes):
            if i != j:
                x1, y1 = nodes_df.loc[i, ["X", "Y"]]
                x2, y2 = nodes_df.loc[j, ["X", "Y"]]
                distance_matrix[i, j] = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

    # Step 3: Combine and prepare data
    nodes_df = nodes_df.merge(demands_df, on="Node")
    return {
        "nodes": nodes_df,
        "distance_matrix": distance_matrix,
        "capacity": capacity,
        "depot": depot
    }

# %% [markdown]
# # Inital feasible routes

# %%
def create_initial_feasible_solution_with_nodes(data):
    depot = data["depot"]  # Depot node (1 in this case)
    capacity = data["capacity"]  # Vehicle capacity
    nodes = data["nodes"]  # Node DataFrame with 'demand' and other details
    distance_matrix = data["distance_matrix"]  # Distance matrix
    customer_nodes = list(data["nodes"]["Node"])  # Extract all node numbers

    # Exclude the depot and segregate into odd and even customer nodes
    odd_customers = [node for node in customer_nodes if node != depot and node % 2 != 0]
    even_customers = [node for node in customer_nodes if node != depot and node % 2 == 0]
    

    # Create initial routes for each customer set
    def generate_routes(customer_set, Vehichle_type):
        initial_routes = {}
        for customer in customer_set:
            # route_id = f"Route_{customer}_{route_type}"  # Unique route ID
            route_id = f"Route_{customer}"  # Unique route ID
            route_cost = (
                2 * distance_matrix[depot - 1][customer - 1]
            )  # Depot -> Customer -> Depot
            # route_demand = nodes.loc[customer -1, "Demand"]  # Demand of the customer
            initial_routes[route_id] = {
                "cost": route_cost,
                "route": [depot, customer, depot],  # Depot -> Customer -> Depot
                "Type" : Vehichle_type,
            }
        return initial_routes

    # Generate routes for odd and even customers
    initial_routes_typeI = generate_routes(odd_customers, "TypeI")
    initial_routes_typeII = generate_routes(even_customers, "TypeII")

    # Combine all routes
    initial_routes = {**initial_routes_typeI, **initial_routes_typeII}

    return initial_routes

# %% [markdown]
# # Create vehicle types

# %%
def create_vehicle_types(data):
    """
    Create a dictionary of vehicle types with capacities based on demand.

    Args:
        data: Dictionary containing 'nodes' and 'capacity'.

    Returns:
        vehicle_types: Dictionary defining capacities for each vehicle type.
    """
    # Extract demands and node information
    nodes = data["nodes"]
    total_capacity = data["capacity"]

    # Segregate odd and even customers
    odd_demands = nodes[nodes["Node"] % 2 != 0]["Demand"]
    even_demands = nodes[nodes["Node"] % 2 == 0]["Demand"]

    # Calculate max demand for odd and even customers
    max_demand_odd = odd_demands.max()
    max_demand_even = even_demands.max()

    # Define vehicle capacities
    vehicle_types = {
        "TypeI": {
            "odd_capacity": max_demand_odd,
            "even_capacity": total_capacity - max_demand_odd
        },
        "TypeII": {
            "odd_capacity": total_capacity - max_demand_even,
            "even_capacity": max_demand_even
            
        }
    }

    return vehicle_types

# %% [markdown]
# # Create customers dictionary

# %%
def create_customers_dict(data):
    """
    Create a dictionary of customers with type and demand.

    Args:
        data: Dictionary containing 'nodes'.

    Returns:
        customers: Dictionary with customer details.
    """
    nodes = data["nodes"]

    customers = {
        row["Node"]: {
            "type": "odd" if row["Node"] % 2 != 0 else "even",
            "demand": row["Demand"]
        }
        for _, row in nodes.iterrows() if row["Node"] != data["depot"]
    }

    return customers

# %% [markdown]
# # Initial feasible solution

# %%
def initialize_and_solve_master_problem(routes, data, vehicle_types, customers, a_ir, route_costs):
    """
    Initializes and solves the Master Problem for the VRP using Gurobi.
    
    Args:
        routes (dict): Dictionary containing route information with the structure:
                       {
                           route_id: {
                               "Type": route_type,
                               "cost": route_cost,
                               "route": [list_of_customers]
                           },
                           ...
                       }
        data (dict): Dictionary containing problem data, specifically `nodes` which
                     includes the customers and depot information.
        vehicle_types (list): List of vehicle types (e.g., ["TypeI", "TypeII"]).
    
    Returns:
        tuple: A tuple containing:
               - solution (dict): Includes:
                   - 'Objective': Objective value of the solution.
                   - 'Variables': Selected route variables and their values.
                   - 'Status': Optimization status (e.g., Optimal, Infeasible).
               - dual_prices (dict): Dictionary of dual prices in the format {customer: dual_price}.
    """
    # Extract customers excluding the depot (Node 1)
    for route_id, route_info in routes.items():
        vehicle_type = route_info["Type"]
        route_costs[(route_id, vehicle_type)] = route_info["cost"]
        a_ir[vehicle_type][route_id] = {
            i: 1 if i in route_info["route"] else 0 for i in customers
        }

    # Initialize the Gurobi model
    master = gp.Model("MasterProblem")
    master.setParam('OutputFlag', 0)
    # Add decision variables for route selection
    lambda_vars = {}
    for route_id, route_info in routes.items():
        vehicle_type = route_info["Type"]
        lambda_vars[(route_id, vehicle_type)] = master.addVar(
            obj=route_info["cost"], vtype=GRB.CONTINUOUS,
            name=f"lambda_{route_id}_{vehicle_type}", lb=0, ub=1
        )

    # Add customer coverage constraints
    customer_constraints = {}
    for customer in customers:
        customer_constraints[customer] = master.addConstr(
            gp.quicksum(
                lambda_vars[(route_id, vehicle_type)] * a_ir[vehicle_type][route_id][customer]
                for route_id, route_info in routes.items()
                for vehicle_type in vehicle_types
                if vehicle_type == route_info["Type"]
            ) == 1,
            name=f"{customer}"
        )

    # Optimize the Master Problem
    master.optimize()

    # Initialize the solution dictionary
    solution = {}
    dual_prices = {}

    if master.Status == GRB.OPTIMAL:
        # Store the objective value
        solution["Objective"] = master.ObjVal

        # Store the variables with their values
        solution["Variables"] = {
            var.VarName: var.X for var in master.getVars() if var.X > 0
        }

        # Store the dual prices for each customer constraint
        for constr in master.getConstrs():
            dual_prices[int(constr.ConstrName)] = constr.Pi

        # Set the status
        solution["Status"] = "Optimal"
    else:
        # If the model isn't optimal, return empty values
        solution["Status"] = "Infeasible or Suboptimal"
        solution["Objective"] = None
        solution["Variables"] = {}

    # Return the solution dictionary and dual prices
    return solution, dual_prices, master, lambda_vars

# %% [markdown]
# # Utility functions

# %%
def create_pricing_problem_graph_multi_vehicle(customers, arcs, dual_prices, vehicle_types):
    """
    Create directed graphs for the pricing problem with customer type-specific vehicle capacities.
    """
    graphs = {}
    
    for vehicle_name, vehicle_capacities in vehicle_types.items():
        # Create graph with multiple resource dimensions
        G = nx.DiGraph(directed=True, n_res=3)  # 4 resources
        
        for (i, j), costs in arcs.items():
            # Resource cost tracking:
            # 1st dimension: total number of customers visited
            # 2nd dimension: total demand for odd customers
            # 3rd dimension: total demand for even customers
            
            # Determine customer type and demand
            j_type = customers.get(j, {}).get('type', None)
            
            # Get demand, default to 0 if not a customer node
            j_demand = customers.get(j, {}).get('demand', 0)
            
            # Initialize resource cost array
            res_cost = np.array([
                1,  # customers visited
                j_demand if j_type == 'odd' else 0,  # odd customer demand
                j_demand if j_type == 'even' else 0  # even customer demand
            ])
            
            # Adjust cost by dual prices
            adjusted_cost = costs - dual_prices.get(i, 0)
            
            # Add edge to graph
            G.add_edge(i, j, res_cost=res_cost, weight=adjusted_cost)
        
        graphs[vehicle_name] = G
    
    return graphs

# Function to solve for each vehicle type
def solve_pricing_problem(graphs, customers, vehicle_types):
    results = {}
    time_limit = 120
    time_elapsed = 0
    for vehicle_name, vehicle_capacities in vehicle_types.items():
        # print("a")
        if time_elapsed > time_limit:
            continue
        G = graphs[vehicle_name]
        # Set resource constraints
        max_res = [
            len(G.edges()),  # max customers visited
            vehicle_capacities['odd_capacity'],  # max odd customer demand
            vehicle_capacities['even_capacity']  # max even customer demand
        ]
        # print(max_res)
        min_res = [0, 0, 0]
        
        # Run bidirectional algorithm
        try:
            time_start = time.time()
            bidirec = BiDirectional(G, max_res, min_res, direction="both", elementary=True, time_limit=5)
            bidirec.run()
            time_end = time.time()
            time_elapsed = time_end - time_start
            results[vehicle_name] = {
                'optimal_path': bidirec.path,
                'total_cost': bidirec.total_cost,
                'odd_capacity': vehicle_capacities['odd_capacity'],
                'even_capacity': vehicle_capacities['even_capacity'],
                'resources_used': bidirec.consumed_resources
            }
        except Exception as e:
            results[vehicle_name] = {
                'error': str(e)
            }
    
    return results


def compute_route_cost(path, depot, distance_matrix):
    """
    Compute the cost of a new route based on the path.
    """
    cost = 0
    for i in range(len(path) - 1):
        if path[i] == "Source":
            cost += distance_matrix[depot - 1][path[i + 1] - 1]
        elif path[i + 1] == "Sink":
            cost += distance_matrix[path[i] - 1][depot - 1]
        else:
            cost += distance_matrix[path[i] - 1][path[i + 1] - 1]
    return cost


def add_new_route_to_master(master, lambda_vars, routes, a_ir, new_route_id, new_route_type, new_route_cost, covered_customers, vehicle_types, customers):
    """
    Add a new route to the master problem.
    """
    # Update routes and a_ir
    a_ir[new_route_type][new_route_id] = {i: 1 if i in covered_customers else 0 for i in customers}
    routes[new_route_id] = {
        "cost": new_route_cost,
        "route": covered_customers,
        "Type": new_route_type,
    }

    # Add new lambda variable
    lambda_vars[(new_route_id, new_route_type)] = master.addVar(
        obj=new_route_cost, vtype=GRB.CONTINUOUS, name=f"lambda_{new_route_id}_{new_route_type}", lb=0, ub=1
    )

    master.update()

    return master


def rebuild_customer_constraints(master, lambda_vars, a_ir, routes, vehicle_types, customers):
    """
    Rebuild customer coverage constraints for the master problem.
    """
    # Remove existing constraints
    for constr in master.getConstrs():
        master.remove(constr)
    customer_constraints = {}
    for customer in customers:
        customer_constraints[customer] = master.addConstr(
            gp.quicksum(
                lambda_vars[(route_id, route_type)] * a_ir[route_type][route_id][customer]
                for route_id, route_info in routes.items()
                for route_type in vehicle_types
                if route_type == route_info["Type"]
            ) == 1,
            name=f"{customer}",
        )
    master.update()
    return master


def solve_master_problem(master):
    """
    Solve the master problem and return the optimal value and variable assignments.
    """
    master.setParam('OutputFlag', 0)
    master.optimize()
    if master.Status == GRB.OPTIMAL:
        master.write("master.lp")
        return master.objVal, {var.VarName: var.X for var in master.getVars()}
        
    else:
        raise Exception(f"Master problem optimization failed with status {master.Status}")


def process_fractional_solution(master, model_path="master.lp"):
    """
    Process fractional solutions by converting the master problem to a MIP.
    """
    # master.write(model_path)
    model = gp.read(model_path)
    model.setParam('OutputFlag', 0)
    model.setParam("MIPFocus", 1)     # Prioritize feasible solutions
    # model.setParam("MIPGap", 1e-4)
    # model.setParam("FeasibilityTol", 1e-6)
    # model.setParam("IntFeasTol", 1e-6)
    # Change variables to binary
    for var in model.getVars():
        var.vtype = GRB.BINARY
    model.update()
    model.optimize()
    gap = model.MIPGap
    for var in master.getVars():
    # if variable is fractional, then get the value from the MIP model
        if var.X < 1- 1e-4 and var.X > 0 + 1e-4:
            for var_mip in model.getVars():
                if var.VarName == var_mip.VarName:
                    var_mip.lb = var_mip.X
                # var_mip.ub = GRB.INFINITY
    model.write("model.lp")

    for var in model.getVars():
        var.vtype = GRB.CONTINUOUS
    model.update()
    model.optimize()

    return model, gap


def extract_dual_prices(model):
    """
    Extract dual prices from the model.
    """
    return {int(constr.ConstrName): constr.Pi for constr in model.getConstrs()}

# %% [markdown]
# # Pricing Problem

# %%
def build_arcs_and_demands(customers, max_customers, depot, distance_matrix, nodes):
    """
    Build arcs and demands for a given set of customers.
    """
    arcs = {}

    for i in customers:
        if i < max_customers:
            arcs[("Source", i)] = distance_matrix[depot - 1][i - 1]
            arcs[(i, "Sink")] = distance_matrix[i - 1][depot - 1]

    for i in customers:
        for j in customers:
            if i != j and i < max_customers and j < max_customers:
                arcs[(i, j)] = distance_matrix[i - 1][j - 1]
                arcs[(j, i)] = distance_matrix[j - 1][i - 1]


    return arcs


def process_customer_set(
    max_customers,
    depot,
    distance_matrix,
    nodes,
    dual_prices,
    capacity,
    routes,
    lambda_vars,
    vehicle_types,
    master,
    a_ir,
    customers,
):
    """
    Process a set of customers (odd or even) by building the pricing problem,
    solving it, and adding the resulting route to the master problem.
    """
    start_pricing = time.time()

    arcs = build_arcs_and_demands(
        customers, max_customers, depot, distance_matrix, nodes
    )

    # Solve the pricing problem
    graphs = create_pricing_problem_graph_multi_vehicle(
        customers, arcs, dual_prices, vehicle_types)
    results = solve_pricing_problem(graphs, customers, vehicle_types)
            
    # Store the cost of the last added route to compare with the next one
    last_route_cost = None

    for vehicle_name, result in results.items():
        # print(result)
        if result['total_cost'] <= -1e-6:
            # If the cost of the current route matches the last route's cost, skip it
            if last_route_cost is not None and abs(result['total_cost'] - last_route_cost) <= 1e-6:
                continue

            # Compute route details
            new_route_cost = compute_route_cost(result["optimal_path"], depot, distance_matrix)
            covered_customers = [
                node for node in result["optimal_path"] if node != "Source" and node != "Sink"
            ]
            new_route_type = vehicle_name
            new_route_id = f"Extra_Route{len(lambda_vars) + 2}"

            # Add the new route to the master problem
            master = add_new_route_to_master(
                master,
                lambda_vars,
                routes,
                a_ir,
                new_route_id,
                new_route_type,
                new_route_cost,
                covered_customers,
                vehicle_types,
                customers,
            )

            # Update the last route cost
            last_route_cost = result['total_cost']

    pricing_time = time.time() - start_pricing

    
    return master, pricing_time

# %% [markdown]
# # Master Problem

# %%
def solve_and_update_master_problem(master, lambda_vars, a_ir, routes, vehicle_types, customers):
    """
    Rebuild customer constraints and solve the master problem.
    """
    start_master = time.time()

    master = rebuild_customer_constraints(master, lambda_vars, a_ir, routes, vehicle_types, customers)
    obj_val, variable_assignments = solve_master_problem(master)

    master_time = time.time() - start_master
    # print(f"Master Problem Objective Value = {obj_val}")
    return master, obj_val, variable_assignments, master_time

# %% [markdown]
# # Column Generation

# %%
def run_column_generation(
    master,
    # odd_customers,
    # even_customers,
    depot,
    distance_matrix,
    nodes,
    dual_prices,
    capacity,
    a_ir,
    routes,
    vehicle_types,
    customers,
    lambda_vars,
    prev_sol,
    increment,
    time_limit,
):
    """
    Run the column generation process for a fixed time limit.
    """
    start_time = time.time()
    iteration = 0
    max_customers = increment + 25
    max_customers = min(max_customers, len(customers))
    # max_customers = len(customers) + 2
    total_pricing_time = 0
    total_master_time = 0

    while time.time() - start_time < time_limit:
        iteration += 1

        
        master, pricing_time_odd = process_customer_set(
            max_customers,
            depot,
            distance_matrix,
            nodes,
            dual_prices,
            capacity,
            routes,
            lambda_vars,
            vehicle_types,
            master,
            a_ir,
            customers,
        )
        total_pricing_time += pricing_time_odd
       

        # Solve and update master problem
        master, obj_val, variable_assignments, master_time = solve_and_update_master_problem(
            master, lambda_vars, a_ir, routes, vehicle_types, customers
        )
        total_master_time += master_time

        # Process fractional solutions in master problem
        mip_model, gap = process_fractional_solution(master)
        dual_prices = extract_dual_prices(mip_model)


        if max_customers ==len(customers):
            prev_sol = obj_val
        # elif obj_val >= prev_sol:  
        #     max_customers += increment
        #     prev_sol = obj_val
        else:
            max_customers += increment
            prev_sol = obj_val
        # print(f"max_customers: {max_customers}")    


    # Output final results
    final_obj_val = mip_model.ObjVal
    final_gap = gap

    print(f"Final Objective Value: {final_obj_val}")
    print(f"Total Pricing Time: {total_pricing_time:.2f} seconds")
    print(f"Total Master Time: {total_master_time:.2f} seconds")
    print(f"Final MIP Gap: {final_gap}")

    return final_obj_val, total_pricing_time, total_master_time, final_gap

# %% [markdown]
# # Single Instance

# %%
def process_instance(file_path):
    """
    Process a single CVRP instance file and return results for the instance.
    """
    # Preprocess the data and initialize the problem
    start_time = time.time()
    
    data = preprocess_cvrp(file_path)
    routes = create_initial_feasible_solution_with_nodes(data)
    vehicle_types = create_vehicle_types(data)
    customers = create_customers_dict(data)

    # Precompute feasibility matrix a_ir and route costs
    a_ir = {t: {} for t in vehicle_types}
    route_costs = {}
    solution, dual_prices, master, lambda_vars = initialize_and_solve_master_problem(
        routes, data, vehicle_types, customers, a_ir, route_costs
    )

    # print(f"dual_prices: {dual_prices}")
    print(f"initial_solution: {solution['Objective']}")
    prev_sol = solution["Objective"]
    # Extract problem-specific parameters
    depot = data["depot"]
    capacity = data["capacity"]
    nodes = data["nodes"]
    distance_matrix = data["distance_matrix"]


    end_time = time.time()
    # Set column generation time limit
    time_limit = 300  - (end_time - start_time)

    # Run column generation and retrieve results
    final_obj_val, total_pricing_time, total_master_time, final_gap = run_column_generation(
        master,
        depot,
        distance_matrix,
        nodes,
        dual_prices,
        capacity,
        a_ir,
        routes,
        vehicle_types,
        customers,
        lambda_vars,
        prev_sol,
        increment = 2,
        time_limit=time_limit,
    )

    # Prepare results dictionary
    result = {
        "Instance": os.path.basename(file_path),  # Use the file name as the instance name
        "Root Node LP Objective": solution["Objective"],
        "Best PnB IP Solution": final_obj_val,
        "GAP": final_gap,
        "Time for Column Generation": total_pricing_time,
        "Time for IP": total_master_time,
    }
    return result

# %% [markdown]
# # Main

# %%
def main():
    """
    Main function to process all VRP instance files in the specified directory
    and return a consolidated DataFrame of results.
    """
    results = []  # Initialize an empty list to store results

    for root, dirs, files in os.walk("./Uchoa-Vrp-Set-X"):
        files = sorted(files)
        for file in files:
            if file.endswith(".vrp"):  # Process only .vrp files
                print(f"----------------{file}----------------")
                file_path = os.path.join(root, file)
                try:
                    result = process_instance(file_path)
                    results.append(result)
                except Exception as e:
                    print(f"Error processing {file}: {e}")

    # Convert results to a Pandas DataFrame
    results_df = pd.DataFrame(results)

    # Save the results to a CSV file (optional)
    results_df.to_csv("cvrp_results_scenario_2.csv", index=False)

    return results_df

# %%
if __name__ == "__main__":
    results_df = main()
    print(results_df)
# Out:
# ----------------X-n101-k25.vrp----------------
# initial_solution: 90010.73456916604
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 102 columns, 111 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 103 columns, 117 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 105 columns, 128 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 106 columns, 134 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 107 columns, 140 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 109 columns, 147 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 110 columns, 151 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 112 columns, 159 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 114 columns, 167 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 115 columns, 170 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 116 columns, 173 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 117 columns, 176 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 118 columns, 179 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 120 columns, 187 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 122 columns, 195 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 124 columns, 202 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 125 columns, 205 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 127 columns, 211 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 129 columns, 217 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 131 columns, 223 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 132 columns, 226 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 134 columns, 232 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 136 columns, 238 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 137 columns, 241 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 100 rows, 138 columns, 244 nonzeros
# Final Objective Value: 70037.5384352986
# Total Pricing Time: 302.82 seconds
# Total Master Time: 0.37 seconds
# Final MIP Gap: 0.0
# ----------------X-n106-k14.vrp----------------
# initial_solution: 182313.70238628561
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 107 columns, 113 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 109 columns, 121 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 111 columns, 129 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 113 columns, 137 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 115 columns, 145 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 117 columns, 153 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 119 columns, 161 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 121 columns, 168 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 123 columns, 175 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 125 columns, 183 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 127 columns, 191 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 129 columns, 198 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 131 columns, 206 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 133 columns, 214 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 135 columns, 222 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 137 columns, 228 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 139 columns, 234 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 141 columns, 240 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 143 columns, 246 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 145 columns, 252 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 147 columns, 258 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 149 columns, 264 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 151 columns, 270 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 153 columns, 276 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 155 columns, 282 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 157 columns, 288 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 159 columns, 294 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 161 columns, 300 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 105 rows, 162 columns, 302 nonzeros
# Final Objective Value: 119171.73287350626
# Total Pricing Time: 298.03 seconds
# Total Master Time: 0.51 seconds
# Final MIP Gap: 0.0
# ----------------X-n110-k13.vrp----------------
# initial_solution: 83028.4565581441
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 111 columns, 117 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 113 columns, 125 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 115 columns, 133 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 117 columns, 140 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 119 columns, 147 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 121 columns, 155 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 123 columns, 162 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 125 columns, 170 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 127 columns, 178 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 129 columns, 186 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 131 columns, 194 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 133 columns, 202 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 135 columns, 210 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 137 columns, 218 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 139 columns, 226 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 141 columns, 234 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 143 columns, 241 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 145 columns, 249 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 147 columns, 255 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 149 columns, 263 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 151 columns, 270 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 153 columns, 278 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 155 columns, 286 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 157 columns, 292 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 159 columns, 298 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 161 columns, 304 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 163 columns, 310 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 165 columns, 316 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 109 rows, 167 columns, 321 nonzeros
# Final Objective Value: 61446.72221979643
# Total Pricing Time: 297.99 seconds
# Total Master Time: 0.53 seconds
# Final MIP Gap: 0.0
# ----------------X-n115-k10.vrp----------------
# initial_solution: 83785.37295681347
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 116 columns, 124 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 118 columns, 132 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 120 columns, 140 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 122 columns, 148 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 124 columns, 156 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 126 columns, 164 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 128 columns, 172 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 130 columns, 179 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 132 columns, 187 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 134 columns, 194 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 136 columns, 201 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 138 columns, 209 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 140 columns, 217 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 142 columns, 224 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 144 columns, 232 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 146 columns, 239 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 148 columns, 245 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 150 columns, 252 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 152 columns, 259 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 154 columns, 265 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 156 columns, 271 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 158 columns, 277 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 160 columns, 283 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 161 columns, 286 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 163 columns, 291 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 165 columns, 296 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 167 columns, 302 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 168 columns, 305 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 114 rows, 169 columns, 308 nonzeros
# Final Objective Value: 63609.8273676055
# Total Pricing Time: 298.03 seconds
# Total Master Time: 0.86 seconds
# Final MIP Gap: 0.0
# ----------------X-n120-k6.vrp----------------
# initial_solution: 171116.06981244124
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 121 columns, 127 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 123 columns, 135 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 125 columns, 143 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 127 columns, 151 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 129 columns, 159 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 131 columns, 167 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 133 columns, 174 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 135 columns, 182 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 137 columns, 190 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 139 columns, 198 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 141 columns, 205 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 143 columns, 211 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 145 columns, 219 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 147 columns, 225 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 149 columns, 232 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 151 columns, 240 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 153 columns, 247 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 155 columns, 253 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 157 columns, 259 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 159 columns, 265 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 161 columns, 271 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 163 columns, 277 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 165 columns, 283 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 167 columns, 289 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 169 columns, 295 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 171 columns, 301 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 173 columns, 307 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 175 columns, 313 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 119 rows, 177 columns, 319 nonzeros
# Final Objective Value: 122974.81655657101
# Total Pricing Time: 297.45 seconds
# Total Master Time: 0.62 seconds
# Final MIP Gap: 0.0
# ----------------X-n125-k30.vrp----------------
# initial_solution: 211720.3625241559
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 126 columns, 132 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 128 columns, 140 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 130 columns, 147 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 132 columns, 155 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 134 columns, 163 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 136 columns, 171 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 138 columns, 179 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 140 columns, 186 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 142 columns, 194 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 144 columns, 202 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 146 columns, 210 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 148 columns, 218 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 150 columns, 226 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 152 columns, 234 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 154 columns, 242 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 156 columns, 250 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 158 columns, 257 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 160 columns, 265 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 162 columns, 273 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 164 columns, 280 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 165 columns, 283 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 167 columns, 289 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 169 columns, 295 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 171 columns, 301 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 173 columns, 307 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 175 columns, 313 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 177 columns, 319 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 179 columns, 325 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 124 rows, 181 columns, 331 nonzeros
# Final Objective Value: 150613.94566465833
# Total Pricing Time: 297.78 seconds
# Total Master Time: 0.65 seconds
# Final MIP Gap: 0.0
# ----------------X-n129-k18.vrp----------------
# initial_solution: 178790.3118318494
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 130 columns, 136 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 132 columns, 144 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 134 columns, 152 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 136 columns, 160 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 138 columns, 168 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 140 columns, 176 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 142 columns, 184 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 144 columns, 192 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 146 columns, 199 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 148 columns, 207 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 150 columns, 214 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 152 columns, 222 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 154 columns, 228 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 156 columns, 236 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 158 columns, 244 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 159 columns, 247 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 161 columns, 254 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 163 columns, 260 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 164 columns, 263 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 166 columns, 269 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 168 columns, 275 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 170 columns, 281 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 172 columns, 287 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 174 columns, 293 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 176 columns, 299 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 178 columns, 305 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 180 columns, 311 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 181 columns, 313 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 128 rows, 183 columns, 319 nonzeros
# Final Objective Value: 127679.30761856238
# Total Pricing Time: 297.90 seconds
# Total Master Time: 0.70 seconds
# Final MIP Gap: 0.0
# ----------------X-n134-k13.vrp----------------
# initial_solution: 93333.48662318356
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 135 columns, 141 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 136 columns, 144 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 138 columns, 152 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 140 columns, 160 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 142 columns, 168 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 144 columns, 176 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 146 columns, 184 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 148 columns, 192 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 150 columns, 200 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 152 columns, 208 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 154 columns, 216 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 156 columns, 224 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 157 columns, 227 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 159 columns, 235 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 161 columns, 242 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 163 columns, 248 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 165 columns, 254 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 167 columns, 260 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 169 columns, 267 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 171 columns, 273 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 172 columns, 275 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 173 columns, 277 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 174 columns, 280 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 176 columns, 286 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 178 columns, 292 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 179 columns, 294 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 180 columns, 297 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 181 columns, 300 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 133 rows, 182 columns, 303 nonzeros
# Final Objective Value: 73642.92940507042
# Total Pricing Time: 297.96 seconds
# Total Master Time: 0.70 seconds
# Final MIP Gap: 0.0
# ----------------X-n139-k10.vrp----------------
# initial_solution: 102289.0783524656
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 140 columns, 146 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 142 columns, 154 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 144 columns, 162 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 146 columns, 170 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 148 columns, 178 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 150 columns, 186 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 152 columns, 193 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 154 columns, 201 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 156 columns, 209 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 158 columns, 217 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 160 columns, 225 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 162 columns, 233 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 164 columns, 241 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 166 columns, 249 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 168 columns, 257 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 170 columns, 264 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 172 columns, 272 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 174 columns, 280 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 176 columns, 288 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 178 columns, 296 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 180 columns, 304 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 182 columns, 311 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 184 columns, 318 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 186 columns, 325 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 188 columns, 331 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 190 columns, 337 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 192 columns, 343 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 194 columns, 349 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 138 rows, 196 columns, 355 nonzeros
# Final Objective Value: 81041.00060448026
# Total Pricing Time: 297.75 seconds
# Total Master Time: 0.75 seconds
# Final MIP Gap: 4.3596296590196515e-05
# ----------------X-n143-k7.vrp----------------
# initial_solution: 221770.89458772886
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 144 columns, 150 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 146 columns, 158 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 148 columns, 164 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 150 columns, 172 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 152 columns, 180 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 154 columns, 188 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 156 columns, 195 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 158 columns, 202 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 160 columns, 210 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 162 columns, 218 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 164 columns, 226 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 166 columns, 234 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 168 columns, 242 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 170 columns, 250 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 172 columns, 258 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 174 columns, 266 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 176 columns, 272 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 178 columns, 280 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 180 columns, 288 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 182 columns, 294 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 184 columns, 302 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 186 columns, 309 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 188 columns, 314 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 190 columns, 320 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 192 columns, 326 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 193 columns, 328 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 194 columns, 331 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 196 columns, 337 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 142 rows, 197 columns, 340 nonzeros
# Final Objective Value: 176497.87432782486
# Total Pricing Time: 298.02 seconds
# Total Master Time: 0.78 seconds
# Final MIP Gap: 0.0
# ----------------X-n148-k46.vrp----------------
# initial_solution: 124352.95972806754
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 148 columns, 151 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 150 columns, 159 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 152 columns, 167 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 153 columns, 171 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 155 columns, 181 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 157 columns, 194 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 159 columns, 202 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 161 columns, 210 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 163 columns, 218 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 165 columns, 227 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 166 columns, 231 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 168 columns, 240 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 170 columns, 251 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 172 columns, 261 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 174 columns, 269 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 176 columns, 277 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 178 columns, 285 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 179 columns, 289 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 181 columns, 297 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 183 columns, 303 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 185 columns, 309 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 187 columns, 315 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 189 columns, 321 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 191 columns, 327 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 193 columns, 333 nonzeros
# Read LP format model from file master.lp
# Reading time = 0.00 seconds
# : 147 rows, 194 columns, 336 nonzeros
# Final Objective Value: 105814.89758915771
# Total Pricing Time: 289.96 seconds
# Total Master Time: 0.73 seconds
# Final MIP Gap: 0.0
#           Instance  Root Node LP Objective  Best PnB IP Solution       GAP  \
# 0   X-n101-k25.vrp            90010.734569          70037.538435  0.000000
# 1   X-n106-k14.vrp           182313.702386         119171.732874  0.000000
# 2   X-n110-k13.vrp            83028.456558          61446.722220  0.000000
# 3   X-n115-k10.vrp            83785.372957          63609.827368  0.000000
# 4    X-n120-k6.vrp           171116.069812         122974.816557  0.000000
# 5   X-n125-k30.vrp           211720.362524         150613.945665  0.000000
# 6   X-n129-k18.vrp           178790.311832         127679.307619  0.000000
# 7   X-n134-k13.vrp            93333.486623          73642.929405  0.000000
# 8   X-n139-k10.vrp           102289.078352          81041.000604  0.000044
# 9    X-n143-k7.vrp           221770.894588         176497.874328  0.000000
# 10  X-n148-k46.vrp           124352.959728         105814.897589  0.000000
#
#     Time for Column Generation  Time for IP
# 0                   302.818282     0.369033
# 1                   298.026343     0.510513
# 2                   297.986691     0.532703
# 3                   298.026088     0.863983
# 4                   297.450028     0.621542
# 5                   297.779949     0.645705
# 6                   297.895447     0.703437
# 7                   297.962407     0.699812
# 8                   297.747512     0.746978
# 9                   298.015445     0.775961
# 10                  289.960753     0.726540
